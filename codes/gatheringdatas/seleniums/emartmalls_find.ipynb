# %%
import pandas as pd

# %%
from selenium import webdriver

# %%
#open chrome browser
browser = webdriver.Chrome(executable_path='../../../../chromedriver.exe') #webdriver_selenium과 web을 연결해주기위함.

# %% [markdown]
# ![image.png](attachment:b1c40187-2d79-4ef9-850c-57f79506c54f.png)

# %%
# url in address window
browser.get('https://emart.ssg.com/disp/category.ssg?dispCtgId=6000214033')

# %% [markdown]
# ### 한개 가져오기

# %%
element_path ='#ty_thmb_view > ul > li:nth-child(1) > div > a > div.mnemitem_tit'
element=browser.find_element_by_css_selector(element_path) # 단수 찾기
type(element)
# Out:
# selenium.webdriver.remote.webelement.WebElement

# %% [markdown]
# ![image.png](attachment:9ebf36dc-5ae3-4963-b31c-d2119b32f48c.png)

# %%
element.text
# Out:
# '노브랜드 반려견패드(중)40*50cm*100매'

# %%
element.get_attribute('class') ## <span class="mnemitem_goods_brand">MOLLY'S</span>
# Out:
# 'mnemitem_tit '

# %%
element_paths ='#swiper-wrapper-1b8cc0079e65f8bb > li.mnemitem_grid_item.swiper-slide.swiper-slide-active > div > div > div.mnemitem_detailbx > div.mnemitem_tx_thmb > a > div.mnemitem_tit'
elementss=browser.find_element_by_css_selector(element_paths)
type(elementss)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[11], line 2
#       1 element_paths ='#swiper-wrapper-1b8cc0079e65f8bb > li.mnemitem_grid_item.swiper-slide.swiper-slide-active > div > div > div.mnemitem_detailbx > div.mnemitem_tx_thmb > a > div.mnemitem_tit'
# ----> 2 elementss=browser.find_element_by_css_selector(element_paths)
#       3 type(elementss)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:598, in WebDriver.find_element_by_css_selector(self, css_selector)
#     582 def find_element_by_css_selector(self, css_selector):
#     583     """
#     584     Finds an element by css selector.
#     585
#    (...)
#     596         element = driver.find_element_by_css_selector('#foo')
#     597     """
# --> 598     return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#
# ...

# %%
elementss.text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 elementss.text
#
# NameError: name 'elementss' is not defined

# %%
elementss.get_attribute('class')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 elementss.get_attribute('class')
#
# NameError: name 'elementss' is not defined

# %% [markdown]
# ### 여러개 가져오기
# - class 이름으로 가져온다.

# %%
elements_path = '.mnemitem_goods_tit'
elements = browser.find_elements_by_css_selector(elements_path)
type(elements), type(elements[0]) ## 이걸 for문으로 돌려서 text로 잡으면 됨.......
# Out:
# (list, selenium.webdriver.remote.webelement.WebElement)

# %%
for webelement in elements : 
    try: 
    # webelement와 동일한 형식은 element.text
        print(webelement.text)
    except:
        pass
# Out:
# 몰리스 쉬야응가 1회용 패드 L 50매
# 몰리스 쉬야응가 1회용 패드 L 50매
# 몰리스 쉬야응가 1회용 패드 M 100매
# 몰리스 쉬야응가 1회용 패드 M 100매
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 반려견패드(중)40*50cm*100매
# 반려견패드(대)60*70cm*45매
# 순살듬뿍 치킨말이스틱 30P (300g)
# 순살듬뿍 오리말이스틱 30P (300g)
# 건강한간식 순살듬뿍 고구마 오리말이 300g
# 건강한간식 순살듬뿍 고구마 치킨말이 300g
# 몰리스픽 반려견 패드 L 45매
# 건강한간식 순살듬뿍 안심오리 300g
# 반려견 사료 10kg
# 몰리스 화이트 스틱껌 소프트치킨 400g
# 템테이션 맛있는 닭고기맛 75g
# 몰리스픽 반려견 패드 M 100매
# 국민가격 DTC 치킨고구마 져키 1kg
# 몰리스 미끄러지지 않는 패드 M 80매
# 몰리스 쉬야응가 1회용 패드 M 100매
# 템테이션 고소한 참치맛 75g
# 건강한간식 순살듬뿍 안심치킨 300g
# 치킨 슬라이스 1kg
# 몰리스 미니 닭가슴살과 연어
# 포켄스 덴탈스틱 후레시 칼슘 S 작은별 220g
# 템테이션 믹스업 참치 연어 새우맛 75g
# 츄잉스틱 플레인요거트 250g
# 자연소재 양고기육포&쌀 460g
# 밥이보약 Dog 튼튼한 관절 8kg (네오2 유통기한 23.10.17)
# 템테이션 풍부한 해산물 맛75g
# 몰리스 3~4회용 패드 L 35매
# 포켄스 덴탈스틱 후레시 블루베리 S 작은별 220g
# [몰리스]프로발란스 어덜트 8kg
# (이마트가 직접 수입한) 딱 한번 반려견 패드 M 200매
# 자연소재 소고기육포스틱 180g
# 국민 두부 고양이 모래(오리지널)
# 포켄스 덴티페어리 M 75g
# 포켄스 덴티페어리 SS 150g
# 맥시 비프져키 800g
# 몰리스미니참치와도미
# [포켄스] 덴티 페어리(소)
# 원더푸드 반려견 고구마말랭이 간식 1kg
# 챠오 츄루 참치 4개입
# 챠오 츄르 참치/해물믹스맛 20개입
# ...

# %% [markdown]
# ### 여러개 element from bundle Webelement

# %%
element_bundle_path='li.mnemitem_grid_item.swiper-slide.swiper-slide-active > div'
element_bundle = browser.find_element_by_css_selector(element_bundle_path)
type(element_bundle)
# Out:
# selenium.webdriver.remote.webelement.WebElement

# %%
element_bundle.text
# Out:
# "장바구니 담기\n쓱배송\n새벽배송 가능\nMOLLY'S 몰리스 쉬야응가 1회용 패드 L 50매\n판매가격\n13,900\n원\n1포 당 278원\n상품평점 5점 만점에\n4.9\n상품평 개수\n(1,478)"

# %%
# 회사명, 제품명(title) 가격(price), 단위가격, 선호도, 해시태그(hashtags)
title = element_bundle.find_element_by_css_selector('.mnemitem_goods_tit').text
price = element_bundle.find_element_by_css_selector('.ssg_price').text
try: 
    
    hashtags=element_bundle.find_element_by_css_selector('mnemitem_tag_linkarea').text # 해시태그는 묶여있으므로 
except : 
    hashtags = str()
    
[title, price, hashtags]
# Out:
# ['몰리스 쉬야응가 1회용 패드 L 50매', '13,900', '']

# %% [markdown]
# ### 묶음에서 list 만들기
# - elements를 list로 만들어서 for문 선택하기.

# %%
elements_bundle_path= 'div.mnemitem_unit'
elements_bundle = browser.find_elements_by_css_selector(elements_bundle_path)
print(len(elements_bundle))
# Out:
# 100

# %%
elements_bundle_list = list()

# %%
# 각 내용들의 bundle을 for문으로 풀어서 list를 만든다. 
for element_bundle in elements_bundle :
    # 회사명, 제품명(title) 가격(price), 단위가격, 선호도, 해시태그(hashtags)
    title = element_bundle.find_element_by_css_selector('.mnemitem_goods_tit').text
    price = element_bundle.find_element_by_css_selector('.ssg_price').text
    try: 
        hashtags=element_bundle.find_element_by_css_selector('mnemitem_tag_linkarea').text # 해시태그는 묶여있으므로 
    except : 
        hashtags = str()
    
        element_bundle_list = [title, price, hashtags] #list라 정의한걸 list에 담는다. 
        elements_bundle_list.append(element_bundle_list)

# %%
elements_bundle_list
# Out:
# [['몰리스 쉬야응가 1회용 패드 L 50매', '13,900', ''],
#  ['몰리스 쉬야응가 1회용 패드 L 50매', '13,900', ''],
#  ['몰리스 쉬야응가 1회용 패드 M 100매', '13,900', ''],
#  ['몰리스 쉬야응가 1회용 패드 M 100매', '13,900', ''],
#  ['', '', ''],
#  ['', '', ''],
#  ['', '', ''],
#  ['', '', ''],
#  ['', '', ''],
#  ['', '', ''],
#  ['', '', ''],
#  ['', '', ''],
#  ['', '', ''],
#  ['', '', ''],
#  ['', '', ''],
#  ['', '', ''],
#  ['', '', ''],
#  ['', '', ''],
#  ['', '', ''],
#  ['', '', ''],
#  ['반려견패드(중)40*50cm*100매', '8,480', ''],
#  ['반려견패드(대)60*70cm*45매', '8,480', ''],
#  ['순살듬뿍 치킨말이스틱 30P (300g)', '9,900', ''],
#  ['순살듬뿍 오리말이스틱 30P (300g)', '9,900', ''],
#  ['건강한간식 순살듬뿍 고구마 오리말이 300g', '9,900', ''],
#  ['건강한간식 순살듬뿍 고구마 치킨말이 300g', '9,900', ''],
#  ['몰리스픽 반려견 패드 L 45매', '8,500', ''],
#  ['건강한간식 순살듬뿍 안심오리 300g', '13,000', ''],
#  ['반려견 사료 10kg', '14,980', ''],
#  ['몰리스 화이트 스틱껌 소프트치킨 400g', '11,000', ''],
#  ['템테이션 맛있는 닭고기맛 75g', '4,300', ''],
#  ['몰리스픽 반려견 패드 M 100매', '8,500', ''],
#  ['국민가격 DTC 치킨고구마 져키 1kg', '12,000', ''],
# ...

# %%
df_pet_list=pd.Data

# %%
elements_bundle_list.to_csv('../../../datasets/emartmall_pet_list.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 elements_bundle_list.to_csv('../../../datasets/emartmall_pet_list.csv')
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %% [markdown]
# ## 이미지 가져오기
# ![image.png](attachment:01f16cc1-c5c8-4106-8b09-339373245546.png)

# %%
# 회사명, 제품명(title) 가격(price), 단위가격, 선호도, 해시태그(hashtags)
title = element_bundle.find_element_by_css_selector('.mnemitem_goods_tit').text
price = element_bundle.find_element_by_css_selector('.ssg_price').text
try: 
    
    hashtags=element_bundle.find_element_by_css_selector('mnemitem_tag_linkarea').text # 해시태그는 묶여있으므로 
except : 
    hashtags = str()
    
image_src = element_bundle.find_element_by_css_selector('.mnemitem_thmb_img').get_attribute('src') # 이미지 class 가져오기

# 이미지 자동 다운로드
# image_src_transform = 'emartmalls_images/image_{}.png'.format()
import urllib.request
urllib.request.urlretrieve(image_src, 'emartmalls_images/image_1.png')
#urllib.request.urlretrieve(image_src, image_src_transform)
[title, price, hashtags, image_src]
## 이걸 for문으로 돌려주면 됨. 대신 png 이름은 'image_{}.png'.format(변수+1)
# Out:
# ['몰리스 쉬야응가 1회용 패드 L 50매',
#  '13,900',
#  '',
#  'https://sitem.ssgcdn.com/03/29/31/item/1000021312903_i1_232.jpg']

# %%
# browser.quit() ## browser닫힘
