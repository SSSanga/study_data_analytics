# %%
# %conda install pymongo

# %%
import pymongo as mg
import pandas as pd

# %%
mg.__version__
# Out:
# '3.12.0'

# %%
client=mg.MongoClient(host='mongodb://localhost:27017')

# %%
databases = client['db_NHIS']

# %%
collection = databases['NSC2_BNC_V2_1']

# %%
cursor = collection.find({})

# %%
list_BND = list(cursor)

# %%
list_BND
# Out:
# [{'_id': ObjectId('64d2fd0b4adce6a8b046e745'),
#   'RN_INDI': 294364,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 200707,
#   'COD1': 'T08-T14',
#   'COD2': 'W00-W19'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e746'),
#   'RN_INDI': 646257,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 200805,
#   'COD1': 'A15-A19'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e747'),
#   'RN_INDI': 733575,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201309,
#   'COD1': 'G30'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e748'),
#   'RN_INDI': 966199,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201409,
#   'COD1': 'J69'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e749'),
#   'RN_INDI': 972598,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201205,
#   'COD1': 'C44'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e74a'),
#   'RN_INDI': 979888,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201101,
#   'COD1': 'R54'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e74b'),
#   'RN_INDI': 991645,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 201504,
#   'COD1': 'K92'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e74c'),
#   'RN_INDI': 1002735,
#   'BTH_YYYY': 1922,
#   'DTH_YYYYMM': 200912,
#   'COD1': 'I63'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e74d'),
#   'RN_INDI': 81830,
#   'BTH_YYYY': 1923,
#   'DTH_YYYYMM': 201106,
#   'COD1': 'K65'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e74e'),
#   'RN_INDI': 126693,
#   'BTH_YYYY': 1924,
#   'DTH_YYYYMM': 201602,
#   'COD1': 'C23'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e74f'),
#   'RN_INDI': 313232,
#   'BTH_YYYY': 1925,
#   'DTH_YYYYMM': 200802,
#   'COD1': 'I21'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e750'),
#   'RN_INDI': 511135,
#   'BTH_YYYY': 1926,
#   'DTH_YYYYMM': 201808,
#   'COD1': 'A00-A09'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e751'),
#   'RN_INDI': 734534,
#   'BTH_YYYY': 1926,
#   'DTH_YYYYMM': 201707,
#   'COD1': 'R54'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e752'),
#   'RN_INDI': 167044,
#   'BTH_YYYY': 1927,
#   'DTH_YYYYMM': 200803,
#   'COD1': 'R54'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e753'),
#   'RN_INDI': 498406,
#   'BTH_YYYY': 1927,
#   'DTH_YYYYMM': 201012,
#   'COD1': 'F00-F09'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e754'),
#   'RN_INDI': 847594,
#   'BTH_YYYY': 1927,
#   'DTH_YYYYMM': 201010,
#   'COD1': 'C34'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e755'),
#   'RN_INDI': 924012,
#   'BTH_YYYY': 1927,
#   'DTH_YYYYMM': 201903,
#   'COD1': 'C22'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e756'),
#   'RN_INDI': 57736,
#   'BTH_YYYY': 1928,
#   'DTH_YYYYMM': 201602,
#   'COD1': 'C34'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e757'),
#   'RN_INDI': 156212,
#   'BTH_YYYY': 1928,
#   'DTH_YYYYMM': 201502,
#   'COD1': 'I64'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e758'),
#   'RN_INDI': 647502,
#   'BTH_YYYY': 1928,
#   'DTH_YYYYMM': 201511,
#   'COD1': 'C22'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e759'),
#   'RN_INDI': 776841,
#   'BTH_YYYY': 1929,
#   'DTH_YYYYMM': 201401,
#   'COD1': 'I20'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e75a'),
#   'RN_INDI': 266922,
#   'BTH_YYYY': 1930},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e75b'),
#   'RN_INDI': 278164,
#   'BTH_YYYY': 1930,
#   'DTH_YYYYMM': 201904,
#   'COD1': 'I63'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e75c'),
#   'RN_INDI': 314204,
#   'BTH_YYYY': 1930,
#   'DTH_YYYYMM': 201109,
#   'COD1': 'I69'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e75d'),
#   'RN_INDI': 394044,
#   'BTH_YYYY': 1930,
#   'DTH_YYYYMM': 201911,
#   'COD1': 'G30'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e75e'),
#   'RN_INDI': 415031,
#   'BTH_YYYY': 1930,
#   'DTH_YYYYMM': 201311,
#   'COD1': 'C22'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e75f'),
#   'RN_INDI': 563280,
#   'BTH_YYYY': 1931},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e760'),
#   'RN_INDI': 750849,
#   'BTH_YYYY': 1931},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e761'),
#   'RN_INDI': 933418,
#   'BTH_YYYY': 1931},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e762'),
#   'RN_INDI': 45815,
#   'BTH_YYYY': 1932},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e763'),
#   'RN_INDI': 60164,
#   'BTH_YYYY': 1932,
#   'DTH_YYYYMM': 201910,
#   'COD1': 'T51-T65',
#   'COD2': 'X00-X09'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e764'),
#   'RN_INDI': 217071,
#   'BTH_YYYY': 1932},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e765'),
#   'RN_INDI': 661358,
#   'BTH_YYYY': 1932},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e766'),
#   'RN_INDI': 780565,
#   'BTH_YYYY': 1932},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e767'),
#   'RN_INDI': 830395,
#   'BTH_YYYY': 1932,
#   'DTH_YYYYMM': 201909,
#   'COD1': 'J80'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e768'),
#   'RN_INDI': 845220,
#   'BTH_YYYY': 1932,
#   'DTH_YYYYMM': 201610,
#   'COD1': 'E11'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e769'),
#   'RN_INDI': 904961,
#   'BTH_YYYY': 1932,
#   'DTH_YYYYMM': 201102,
#   'COD1': 'I50'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e76a'),
#   'RN_INDI': 128764,
#   'BTH_YYYY': 1933},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e76b'),
#   'RN_INDI': 447304,
#   'BTH_YYYY': 1933},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e76c'),
#   'RN_INDI': 661690,
#   'BTH_YYYY': 1933},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e76d'),
#   'RN_INDI': 759704,
#   'BTH_YYYY': 1933},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e76e'),
#   'RN_INDI': 817724,
#   'BTH_YYYY': 1933,
#   'DTH_YYYYMM': 200907,
#   'COD1': 'I21'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e76f'),
#   'RN_INDI': 891674,
#   'BTH_YYYY': 1933},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e770'),
#   'RN_INDI': 35364,
#   'BTH_YYYY': 1934,
#   'DTH_YYYYMM': 201503,
#   'COD1': 'I25'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e771'),
#   'RN_INDI': 374055,
#   'BTH_YYYY': 1934},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e772'),
#   'RN_INDI': 732273,
#   'BTH_YYYY': 1934},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e773'),
#   'RN_INDI': 823068,
#   'BTH_YYYY': 1934,
#   'DTH_YYYYMM': 202105},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e774'),
#   'RN_INDI': 830143,
#   'BTH_YYYY': 1934},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e775'),
#   'RN_INDI': 863928,
#   'BTH_YYYY': 1934,
#   'DTH_YYYYMM': 200812,
#   'COD1': 'T08-T14',
#   'COD2': 'V20-V29'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e776'),
#   'RN_INDI': 929045,
#   'BTH_YYYY': 1934,
#   'DTH_YYYYMM': 201008,
#   'COD1': 'J60'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e777'),
#   'RN_INDI': 6088,
#   'BTH_YYYY': 1935,
#   'DTH_YYYYMM': 201610,
#   'COD1': 'I46'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e778'),
#   'RN_INDI': 286730,
#   'BTH_YYYY': 1935},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e779'),
#   'RN_INDI': 338024,
#   'BTH_YYYY': 1935,
#   'DTH_YYYYMM': 201904,
#   'COD1': 'C15'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e77a'),
#   'RN_INDI': 356231,
#   'BTH_YYYY': 1935},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e77b'),
#   'RN_INDI': 940080,
#   'BTH_YYYY': 1935},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e77c'),
#   'RN_INDI': 451174,
#   'BTH_YYYY': 1936,
#   'DTH_YYYYMM': 201207,
#   'COD1': 'C90'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e77d'),
#   'RN_INDI': 460880,
#   'BTH_YYYY': 1936},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e77e'),
#   'RN_INDI': 752341,
#   'BTH_YYYY': 1936,
#   'DTH_YYYYMM': 201905,
#   'COD1': 'B00-B09'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e77f'),
#   'RN_INDI': 769362,
#   'BTH_YYYY': 1936},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e780'),
#   'RN_INDI': 892931,
#   'BTH_YYYY': 1936},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e781'),
#   'RN_INDI': 982512,
#   'BTH_YYYY': 1936,
#   'DTH_YYYYMM': 201009,
#   'COD1': 'C34'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e782'),
#   'RN_INDI': 986085,
#   'BTH_YYYY': 1936,
#   'DTH_YYYYMM': 201212,
#   'COD1': 'J44'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e783'),
#   'RN_INDI': 121652,
#   'BTH_YYYY': 1937,
#   'DTH_YYYYMM': 202010},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e784'),
#   'RN_INDI': 211587,
#   'BTH_YYYY': 1937},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e785'),
#   'RN_INDI': 639262,
#   'BTH_YYYY': 1937,
#   'DTH_YYYYMM': 201007,
#   'COD1': 'C16'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e786'),
#   'RN_INDI': 192153,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e787'),
#   'RN_INDI': 340919,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e788'),
#   'RN_INDI': 466622,
#   'BTH_YYYY': 1938,
#   'DTH_YYYYMM': 201409,
#   'COD1': 'T15-T19',
#   'COD2': 'W75-W84'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e789'),
#   'RN_INDI': 602767,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e78a'),
#   'RN_INDI': 631088,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e78b'),
#   'RN_INDI': 645281,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e78c'),
#   'RN_INDI': 687590,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e78d'),
#   'RN_INDI': 782784,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e78e'),
#   'RN_INDI': 785193,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e78f'),
#   'RN_INDI': 904381,
#   'BTH_YYYY': 1938},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e790'),
#   'RN_INDI': 136163,
#   'BTH_YYYY': 1939},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e791'),
#   'RN_INDI': 678141,
#   'BTH_YYYY': 1939,
#   'DTH_YYYYMM': 201210,
#   'COD1': 'T15-T19',
#   'COD2': 'W75-W84'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e792'),
#   'RN_INDI': 734409,
#   'BTH_YYYY': 1939,
#   'DTH_YYYYMM': 201906,
#   'COD1': 'N18'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e793'),
#   'RN_INDI': 752588,
#   'BTH_YYYY': 1939},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e794'),
#   'RN_INDI': 973001,
#   'BTH_YYYY': 1939},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e795'),
#   'RN_INDI': 202610,
#   'BTH_YYYY': 1940},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e796'),
#   'RN_INDI': 588655,
#   'BTH_YYYY': 1940,
#   'DTH_YYYYMM': 201508,
#   'COD1': 'J81'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e797'),
#   'RN_INDI': 596321,
#   'BTH_YYYY': 1940},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e798'),
#   'RN_INDI': 674283,
#   'BTH_YYYY': 1940},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e799'),
#   'RN_INDI': 773366,
#   'BTH_YYYY': 1940},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e79a'),
#   'RN_INDI': 195032,
#   'BTH_YYYY': 1941},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e79b'),
#   'RN_INDI': 281502,
#   'BTH_YYYY': 1941},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e79c'),
#   'RN_INDI': 335999,
#   'BTH_YYYY': 1941},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e79d'),
#   'RN_INDI': 399667,
#   'BTH_YYYY': 1941},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e79e'),
#   'RN_INDI': 669847,
#   'BTH_YYYY': 1941,
#   'DTH_YYYYMM': 202011},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e79f'),
#   'RN_INDI': 874400,
#   'BTH_YYYY': 1941},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7a0'),
#   'RN_INDI': 19442,
#   'BTH_YYYY': 1942,
#   'DTH_YYYYMM': 202003},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7a1'),
#   'RN_INDI': 214085,
#   'BTH_YYYY': 1942},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7a2'),
#   'RN_INDI': 499129,
#   'BTH_YYYY': 1942},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7a3'),
#   'RN_INDI': 526484,
#   'BTH_YYYY': 1942},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7a4'),
#   'RN_INDI': 594404,
#   'BTH_YYYY': 1942},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7a5'),
#   'RN_INDI': 777023,
#   'BTH_YYYY': 1942},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7a6'),
#   'RN_INDI': 793097,
#   'BTH_YYYY': 1942},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7a7'),
#   'RN_INDI': 99170,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7a8'),
#   'RN_INDI': 179035,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7a9'),
#   'RN_INDI': 293594,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7aa'),
#   'RN_INDI': 411541,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7ab'),
#   'RN_INDI': 561959,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7ac'),
#   'RN_INDI': 658248,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7ad'),
#   'RN_INDI': 782489,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7ae'),
#   'RN_INDI': 905179,
#   'BTH_YYYY': 1943},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7af'),
#   'RN_INDI': 138056,
#   'BTH_YYYY': 1944},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7b0'),
#   'RN_INDI': 423141,
#   'BTH_YYYY': 1944},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7b1'),
#   'RN_INDI': 462208,
#   'BTH_YYYY': 1944},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7b2'),
#   'RN_INDI': 641654,
#   'BTH_YYYY': 1944},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7b3'),
#   'RN_INDI': 652355,
#   'BTH_YYYY': 1944},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7b4'),
#   'RN_INDI': 668008,
#   'BTH_YYYY': 1944,
#   'DTH_YYYYMM': 201909,
#   'COD1': 'I50'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7b5'),
#   'RN_INDI': 699543,
#   'BTH_YYYY': 1944},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7b6'),
#   'RN_INDI': 915167,
#   'BTH_YYYY': 1944},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7b7'),
#   'RN_INDI': 267631,
#   'BTH_YYYY': 1945},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7b8'),
#   'RN_INDI': 325107,
#   'BTH_YYYY': 1945},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7b9'),
#   'RN_INDI': 347480,
#   'BTH_YYYY': 1945},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7ba'),
#   'RN_INDI': 400685,
#   'BTH_YYYY': 1945},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7bb'),
#   'RN_INDI': 434429,
#   'BTH_YYYY': 1945},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7bc'),
#   'RN_INDI': 459027,
#   'BTH_YYYY': 1945},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7bd'),
#   'RN_INDI': 685794,
#   'BTH_YYYY': 1945},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7be'),
#   'RN_INDI': 224374,
#   'BTH_YYYY': 1946},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7bf'),
#   'RN_INDI': 516621,
#   'BTH_YYYY': 1946},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7c0'),
#   'RN_INDI': 635052,
#   'BTH_YYYY': 1946},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7c1'),
#   'RN_INDI': 800215,
#   'BTH_YYYY': 1946,
#   'DTH_YYYYMM': 202103},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7c2'),
#   'RN_INDI': 838106,
#   'BTH_YYYY': 1946},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7c3'),
#   'RN_INDI': 972420,
#   'BTH_YYYY': 1946},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7c4'),
#   'RN_INDI': 991935,
#   'BTH_YYYY': 1946},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7c5'),
#   'RN_INDI': 49564,
#   'BTH_YYYY': 1947,
#   'DTH_YYYYMM': 201509,
#   'COD1': 'C25'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7c6'),
#   'RN_INDI': 73591,
#   'BTH_YYYY': 1947,
#   'DTH_YYYYMM': 202105},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7c7'),
#   'RN_INDI': 459355,
#   'BTH_YYYY': 1947,
#   'DTH_YYYYMM': 200902,
#   'COD1': 'S00-S09',
#   'COD2': 'V01-V09'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7c8'),
#   'RN_INDI': 557550,
#   'BTH_YYYY': 1947,
#   'DTH_YYYYMM': 202008},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7c9'),
#   'RN_INDI': 618926,
#   'BTH_YYYY': 1947},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7ca'),
#   'RN_INDI': 989524,
#   'BTH_YYYY': 1947},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7cb'),
#   'RN_INDI': 43189,
#   'BTH_YYYY': 1948},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7cc'),
#   'RN_INDI': 335758,
#   'BTH_YYYY': 1948},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7cd'),
#   'RN_INDI': 352171,
#   'BTH_YYYY': 1948,
#   'DTH_YYYYMM': 202002},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7ce'),
#   'RN_INDI': 435393,
#   'BTH_YYYY': 1948},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7cf'),
#   'RN_INDI': 557288,
#   'BTH_YYYY': 1948},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7d0'),
#   'RN_INDI': 646251,
#   'BTH_YYYY': 1948},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7d1'),
#   'RN_INDI': 794513,
#   'BTH_YYYY': 1948},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7d2'),
#   'RN_INDI': 992976,
#   'BTH_YYYY': 1948},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7d3'),
#   'RN_INDI': 6091,
#   'BTH_YYYY': 1949},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7d4'),
#   'RN_INDI': 174366,
#   'BTH_YYYY': 1949},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7d5'),
#   'RN_INDI': 291793,
#   'BTH_YYYY': 1949},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7d6'),
#   'RN_INDI': 293083,
#   'BTH_YYYY': 1949,
#   'DTH_YYYYMM': 200712,
#   'COD1': 'K70'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7d7'),
#   'RN_INDI': 346560,
#   'BTH_YYYY': 1949},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7d8'),
#   'RN_INDI': 400705,
#   'BTH_YYYY': 1949},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7d9'),
#   'RN_INDI': 491396,
#   'BTH_YYYY': 1949},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7da'),
#   'RN_INDI': 688356,
#   'BTH_YYYY': 1949},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7db'),
#   'RN_INDI': 13486,
#   'BTH_YYYY': 1950},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7dc'),
#   'RN_INDI': 77520,
#   'BTH_YYYY': 1950,
#   'DTH_YYYYMM': 201811,
#   'COD1': 'C25'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7dd'),
#   'RN_INDI': 268861,
#   'BTH_YYYY': 1950},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7de'),
#   'RN_INDI': 391223,
#   'BTH_YYYY': 1950,
#   'DTH_YYYYMM': 202007},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7df'),
#   'RN_INDI': 418141,
#   'BTH_YYYY': 1950},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7e0'),
#   'RN_INDI': 577109,
#   'BTH_YYYY': 1950},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7e1'),
#   'RN_INDI': 694471,
#   'BTH_YYYY': 1950},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7e2'),
#   'RN_INDI': 770773,
#   'BTH_YYYY': 1950,
#   'DTH_YYYYMM': 201806,
#   'COD1': 'E11'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7e3'),
#   'RN_INDI': 26921,
#   'BTH_YYYY': 1951},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7e4'),
#   'RN_INDI': 51743,
#   'BTH_YYYY': 1951},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7e5'),
#   'RN_INDI': 136900,
#   'BTH_YYYY': 1951},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7e6'),
#   'RN_INDI': 254163,
#   'BTH_YYYY': 1951},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7e7'),
#   'RN_INDI': 513026,
#   'BTH_YYYY': 1951},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7e8'),
#   'RN_INDI': 738834,
#   'BTH_YYYY': 1951},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7e9'),
#   'RN_INDI': 889348,
#   'BTH_YYYY': 1951},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7ea'),
#   'RN_INDI': 165492,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7eb'),
#   'RN_INDI': 183863,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7ec'),
#   'RN_INDI': 216674,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7ed'),
#   'RN_INDI': 326051,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7ee'),
#   'RN_INDI': 354997,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7ef'),
#   'RN_INDI': 375650,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7f0'),
#   'RN_INDI': 398604,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7f1'),
#   'RN_INDI': 414026,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7f2'),
#   'RN_INDI': 547878,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7f3'),
#   'RN_INDI': 689623,
#   'BTH_YYYY': 1952,
#   'DTH_YYYYMM': 201110,
#   'COD1': 'J84'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7f4'),
#   'RN_INDI': 733753,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7f5'),
#   'RN_INDI': 941010,
#   'BTH_YYYY': 1952},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7f6'),
#   'RN_INDI': 4392,
#   'BTH_YYYY': 1953,
#   'DTH_YYYYMM': 201204,
#   'COD1': 'N18'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7f7'),
#   'RN_INDI': 91952,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7f8'),
#   'RN_INDI': 104229,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7f9'),
#   'RN_INDI': 171740,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7fa'),
#   'RN_INDI': 317094,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7fb'),
#   'RN_INDI': 359683,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7fc'),
#   'RN_INDI': 441482,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7fd'),
#   'RN_INDI': 474187,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7fe'),
#   'RN_INDI': 534288,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e7ff'),
#   'RN_INDI': 649286,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e800'),
#   'RN_INDI': 680896,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e801'),
#   'RN_INDI': 734772,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e802'),
#   'RN_INDI': 778752,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e803'),
#   'RN_INDI': 965940,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e804'),
#   'RN_INDI': 997203,
#   'BTH_YYYY': 1953},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e805'),
#   'RN_INDI': 267582,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e806'),
#   'RN_INDI': 366576,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e807'),
#   'RN_INDI': 396281,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e808'),
#   'RN_INDI': 405681,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e809'),
#   'RN_INDI': 632149,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e80a'),
#   'RN_INDI': 744818,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e80b'),
#   'RN_INDI': 757675,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e80c'),
#   'RN_INDI': 1003337,
#   'BTH_YYYY': 1954},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e80d'),
#   'RN_INDI': 111233,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e80e'),
#   'RN_INDI': 184935,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e80f'),
#   'RN_INDI': 322714,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e810'),
#   'RN_INDI': 365179,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e811'),
#   'RN_INDI': 489958,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e812'),
#   'RN_INDI': 526975,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e813'),
#   'RN_INDI': 576619,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e814'),
#   'RN_INDI': 616301,
#   'BTH_YYYY': 1955,
#   'DTH_YYYYMM': 201012,
#   'COD1': 'T66-T78',
#   'COD2': 'X60-X84'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e815'),
#   'RN_INDI': 691360,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e816'),
#   'RN_INDI': 698203,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e817'),
#   'RN_INDI': 724356,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e818'),
#   'RN_INDI': 767776,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e819'),
#   'RN_INDI': 855875,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e81a'),
#   'RN_INDI': 961636,
#   'BTH_YYYY': 1955},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e81b'),
#   'RN_INDI': 47686,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e81c'),
#   'RN_INDI': 446544,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e81d'),
#   'RN_INDI': 479670,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e81e'),
#   'RN_INDI': 511798,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e81f'),
#   'RN_INDI': 534381,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e820'),
#   'RN_INDI': 544817,
#   'BTH_YYYY': 1956,
#   'DTH_YYYYMM': 201912,
#   'COD1': 'C83'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e821'),
#   'RN_INDI': 593807,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e822'),
#   'RN_INDI': 658643,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e823'),
#   'RN_INDI': 712367,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e824'),
#   'RN_INDI': 758449,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e825'),
#   'RN_INDI': 759109,
#   'BTH_YYYY': 1956},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e826'),
#   'RN_INDI': 138777,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e827'),
#   'RN_INDI': 190943,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e828'),
#   'RN_INDI': 217974,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e829'),
#   'RN_INDI': 280296,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e82a'),
#   'RN_INDI': 291326,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e82b'),
#   'RN_INDI': 326525,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e82c'),
#   'RN_INDI': 411755,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e82d'),
#   'RN_INDI': 567118,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e82e'),
#   'RN_INDI': 573784,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e82f'),
#   'RN_INDI': 946035,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e830'),
#   'RN_INDI': 953845,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e831'),
#   'RN_INDI': 996319,
#   'BTH_YYYY': 1957},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e832'),
#   'RN_INDI': 36941,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e833'),
#   'RN_INDI': 174428,
#   'BTH_YYYY': 1958,
#   'DTH_YYYYMM': 200709,
#   'COD1': 'F10-F19'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e834'),
#   'RN_INDI': 201324,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e835'),
#   'RN_INDI': 312513,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e836'),
#   'RN_INDI': 399523,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e837'),
#   'RN_INDI': 635359,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e838'),
#   'RN_INDI': 721929,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e839'),
#   'RN_INDI': 783723,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e83a'),
#   'RN_INDI': 934842,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e83b'),
#   'RN_INDI': 956347,
#   'BTH_YYYY': 1958},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e83c'),
#   'RN_INDI': 6907,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e83d'),
#   'RN_INDI': 139052,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e83e'),
#   'RN_INDI': 150062,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e83f'),
#   'RN_INDI': 255665,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e840'),
#   'RN_INDI': 302152,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e841'),
#   'RN_INDI': 323839,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e842'),
#   'RN_INDI': 362517,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e843'),
#   'RN_INDI': 474121,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e844'),
#   'RN_INDI': 586351,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e845'),
#   'RN_INDI': 596632,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e846'),
#   'RN_INDI': 741694,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e847'),
#   'RN_INDI': 753025,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e848'),
#   'RN_INDI': 834250,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e849'),
#   'RN_INDI': 909636,
#   'BTH_YYYY': 1959,
#   'DTH_YYYYMM': 201608,
#   'COD1': 'N17'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e84a'),
#   'RN_INDI': 941014,
#   'BTH_YYYY': 1959},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e84b'),
#   'RN_INDI': 28967,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e84c'),
#   'RN_INDI': 45383,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e84d'),
#   'RN_INDI': 120601,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e84e'),
#   'RN_INDI': 142037,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e84f'),
#   'RN_INDI': 183094,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e850'),
#   'RN_INDI': 237870,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e851'),
#   'RN_INDI': 249100,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e852'),
#   'RN_INDI': 253557,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e853'),
#   'RN_INDI': 257985,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e854'),
#   'RN_INDI': 276428,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e855'),
#   'RN_INDI': 315899,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e856'),
#   'RN_INDI': 323550,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e857'),
#   'RN_INDI': 350191,
#   'BTH_YYYY': 1960,
#   'DTH_YYYYMM': 202102},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e858'),
#   'RN_INDI': 479772,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e859'),
#   'RN_INDI': 733272,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e85a'),
#   'RN_INDI': 764856,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e85b'),
#   'RN_INDI': 784523,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e85c'),
#   'RN_INDI': 800326,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e85d'),
#   'RN_INDI': 848771,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e85e'),
#   'RN_INDI': 849697,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e85f'),
#   'RN_INDI': 857971,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e860'),
#   'RN_INDI': 874557,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e861'),
#   'RN_INDI': 902791,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e862'),
#   'RN_INDI': 933428,
#   'BTH_YYYY': 1960},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e863'),
#   'RN_INDI': 62782,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e864'),
#   'RN_INDI': 181948,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e865'),
#   'RN_INDI': 213565,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e866'),
#   'RN_INDI': 272276,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e867'),
#   'RN_INDI': 272384,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e868'),
#   'RN_INDI': 280180,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e869'),
#   'RN_INDI': 417450,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e86a'),
#   'RN_INDI': 607228,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e86b'),
#   'RN_INDI': 629778,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e86c'),
#   'RN_INDI': 643505,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e86d'),
#   'RN_INDI': 774338,
#   'BTH_YYYY': 1961,
#   'DTH_YYYYMM': 201711,
#   'COD1': 'F10-F19'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e86e'),
#   'RN_INDI': 843214,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e86f'),
#   'RN_INDI': 888311,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e870'),
#   'RN_INDI': 899496,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e871'),
#   'RN_INDI': 913378,
#   'BTH_YYYY': 1961},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e872'),
#   'RN_INDI': 13456,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e873'),
#   'RN_INDI': 54310,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e874'),
#   'RN_INDI': 89343,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e875'),
#   'RN_INDI': 231812,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e876'),
#   'RN_INDI': 244210,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e877'),
#   'RN_INDI': 290156,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e878'),
#   'RN_INDI': 358065,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e879'),
#   'RN_INDI': 417917,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e87a'),
#   'RN_INDI': 616341,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e87b'),
#   'RN_INDI': 630247,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e87c'),
#   'RN_INDI': 727759,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e87d'),
#   'RN_INDI': 761432,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e87e'),
#   'RN_INDI': 784394,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e87f'),
#   'RN_INDI': 786621,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e880'),
#   'RN_INDI': 798660,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e881'),
#   'RN_INDI': 950140,
#   'BTH_YYYY': 1962},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e882'),
#   'RN_INDI': 8123,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e883'),
#   'RN_INDI': 64464,
#   'BTH_YYYY': 1963,
#   'DTH_YYYYMM': 201811,
#   'COD1': 'C34'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e884'),
#   'RN_INDI': 171250,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e885'),
#   'RN_INDI': 197204,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e886'),
#   'RN_INDI': 293850,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e887'),
#   'RN_INDI': 334789,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e888'),
#   'RN_INDI': 507721,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e889'),
#   'RN_INDI': 513398,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e88a'),
#   'RN_INDI': 556042,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e88b'),
#   'RN_INDI': 699248,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e88c'),
#   'RN_INDI': 780676,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e88d'),
#   'RN_INDI': 790573,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e88e'),
#   'RN_INDI': 806729,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e88f'),
#   'RN_INDI': 866221,
#   'BTH_YYYY': 1963},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e890'),
#   'RN_INDI': 58754,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e891'),
#   'RN_INDI': 62197,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e892'),
#   'RN_INDI': 82185,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e893'),
#   'RN_INDI': 83610,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e894'),
#   'RN_INDI': 114351,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e895'),
#   'RN_INDI': 223544,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e896'),
#   'RN_INDI': 328999,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e897'),
#   'RN_INDI': 332538,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e898'),
#   'RN_INDI': 338796,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e899'),
#   'RN_INDI': 406502,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e89a'),
#   'RN_INDI': 557653,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e89b'),
#   'RN_INDI': 637891,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e89c'),
#   'RN_INDI': 646640,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e89d'),
#   'RN_INDI': 777069,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e89e'),
#   'RN_INDI': 961315,
#   'BTH_YYYY': 1964},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e89f'),
#   'RN_INDI': 212874,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8a0'),
#   'RN_INDI': 254322,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8a1'),
#   'RN_INDI': 436198,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8a2'),
#   'RN_INDI': 444084,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8a3'),
#   'RN_INDI': 481258,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8a4'),
#   'RN_INDI': 507438,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8a5'),
#   'RN_INDI': 529564,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8a6'),
#   'RN_INDI': 594837,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8a7'),
#   'RN_INDI': 643311,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8a8'),
#   'RN_INDI': 649389,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8a9'),
#   'RN_INDI': 737330,
#   'BTH_YYYY': 1965,
#   'DTH_YYYYMM': 201205,
#   'COD1': 'C50'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8aa'),
#   'RN_INDI': 771454,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8ab'),
#   'RN_INDI': 1010728,
#   'BTH_YYYY': 1965},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8ac'),
#   'RN_INDI': 13228,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8ad'),
#   'RN_INDI': 93403,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8ae'),
#   'RN_INDI': 194296,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8af'),
#   'RN_INDI': 250810,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8b0'),
#   'RN_INDI': 290097,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8b1'),
#   'RN_INDI': 327665,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8b2'),
#   'RN_INDI': 336032,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8b3'),
#   'RN_INDI': 376807,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8b4'),
#   'RN_INDI': 388840,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8b5'),
#   'RN_INDI': 393656,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8b6'),
#   'RN_INDI': 400003,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8b7'),
#   'RN_INDI': 419667,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8b8'),
#   'RN_INDI': 565772,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8b9'),
#   'RN_INDI': 629788,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8ba'),
#   'RN_INDI': 678128,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8bb'),
#   'RN_INDI': 683071,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8bc'),
#   'RN_INDI': 727629,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8bd'),
#   'RN_INDI': 879081,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8be'),
#   'RN_INDI': 967749,
#   'BTH_YYYY': 1966},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8bf'),
#   'RN_INDI': 60947,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8c0'),
#   'RN_INDI': 123392,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8c1'),
#   'RN_INDI': 137557,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8c2'),
#   'RN_INDI': 233697,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8c3'),
#   'RN_INDI': 245082,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8c4'),
#   'RN_INDI': 286410,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8c5'),
#   'RN_INDI': 305719,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8c6'),
#   'RN_INDI': 440063,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8c7'),
#   'RN_INDI': 490275,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8c8'),
#   'RN_INDI': 503543,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8c9'),
#   'RN_INDI': 506073,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8ca'),
#   'RN_INDI': 552401,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8cb'),
#   'RN_INDI': 582426,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8cc'),
#   'RN_INDI': 622548,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8cd'),
#   'RN_INDI': 689166,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8ce'),
#   'RN_INDI': 752392,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8cf'),
#   'RN_INDI': 794554,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8d0'),
#   'RN_INDI': 817856,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8d1'),
#   'RN_INDI': 834908,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8d2'),
#   'RN_INDI': 846679,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8d3'),
#   'RN_INDI': 959064,
#   'BTH_YYYY': 1967},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8d4'),
#   'RN_INDI': 6616,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8d5'),
#   'RN_INDI': 17781,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8d6'),
#   'RN_INDI': 74642,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8d7'),
#   'RN_INDI': 113162,
#   'BTH_YYYY': 1968,
#   'DTH_YYYYMM': 201508,
#   'COD1': 'K70'},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8d8'),
#   'RN_INDI': 158220,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8d9'),
#   'RN_INDI': 170619,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8da'),
#   'RN_INDI': 187296,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8db'),
#   'RN_INDI': 297639,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8dc'),
#   'RN_INDI': 376684,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8dd'),
#   'RN_INDI': 414618,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8de'),
#   'RN_INDI': 417458,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8df'),
#   'RN_INDI': 439422,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8e0'),
#   'RN_INDI': 492073,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8e1'),
#   'RN_INDI': 553458,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8e2'),
#   'RN_INDI': 554157,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8e3'),
#   'RN_INDI': 559413,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8e4'),
#   'RN_INDI': 560319,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8e5'),
#   'RN_INDI': 565652,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8e6'),
#   'RN_INDI': 655520,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8e7'),
#   'RN_INDI': 700176,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8e8'),
#   'RN_INDI': 745298,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8e9'),
#   'RN_INDI': 780304,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8ea'),
#   'RN_INDI': 795056,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8eb'),
#   'RN_INDI': 815235,
#   'BTH_YYYY': 1968},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8ec'),
#   'RN_INDI': 89809,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8ed'),
#   'RN_INDI': 127572,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8ee'),
#   'RN_INDI': 163932,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8ef'),
#   'RN_INDI': 176697,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8f0'),
#   'RN_INDI': 213984,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8f1'),
#   'RN_INDI': 241985,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8f2'),
#   'RN_INDI': 285810,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8f3'),
#   'RN_INDI': 313646,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8f4'),
#   'RN_INDI': 328638,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8f5'),
#   'RN_INDI': 350246,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8f6'),
#   'RN_INDI': 442751,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8f7'),
#   'RN_INDI': 466008,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8f8'),
#   'RN_INDI': 485457,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8f9'),
#   'RN_INDI': 505466,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8fa'),
#   'RN_INDI': 533519,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8fb'),
#   'RN_INDI': 638590,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8fc'),
#   'RN_INDI': 646093,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8fd'),
#   'RN_INDI': 828266,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8fe'),
#   'RN_INDI': 905465,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e8ff'),
#   'RN_INDI': 933678,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e900'),
#   'RN_INDI': 1000068,
#   'BTH_YYYY': 1969},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e901'),
#   'RN_INDI': 85360,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e902'),
#   'RN_INDI': 92707,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e903'),
#   'RN_INDI': 253233,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e904'),
#   'RN_INDI': 262759,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e905'),
#   'RN_INDI': 332455,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e906'),
#   'RN_INDI': 481221,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e907'),
#   'RN_INDI': 561326,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e908'),
#   'RN_INDI': 604549,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e909'),
#   'RN_INDI': 639227,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e90a'),
#   'RN_INDI': 677413,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e90b'),
#   'RN_INDI': 843082,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e90c'),
#   'RN_INDI': 905593,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e90d'),
#   'RN_INDI': 913018,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e90e'),
#   'RN_INDI': 932986,
#   'BTH_YYYY': 1970},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e90f'),
#   'RN_INDI': 8651,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e910'),
#   'RN_INDI': 14754,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e911'),
#   'RN_INDI': 53861,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e912'),
#   'RN_INDI': 62118,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e913'),
#   'RN_INDI': 172716,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e914'),
#   'RN_INDI': 182649,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e915'),
#   'RN_INDI': 241974,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e916'),
#   'RN_INDI': 262509,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e917'),
#   'RN_INDI': 312669,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e918'),
#   'RN_INDI': 315946,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e919'),
#   'RN_INDI': 367659,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e91a'),
#   'RN_INDI': 378613,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e91b'),
#   'RN_INDI': 413591,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e91c'),
#   'RN_INDI': 488703,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e91d'),
#   'RN_INDI': 545148,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e91e'),
#   'RN_INDI': 607798,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e91f'),
#   'RN_INDI': 822808,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e920'),
#   'RN_INDI': 961069,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e921'),
#   'RN_INDI': 970269,
#   'BTH_YYYY': 1971},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e922'),
#   'RN_INDI': 55619,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e923'),
#   'RN_INDI': 92721,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e924'),
#   'RN_INDI': 98010,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e925'),
#   'RN_INDI': 412233,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e926'),
#   'RN_INDI': 439222,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e927'),
#   'RN_INDI': 449936,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e928'),
#   'RN_INDI': 561313,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e929'),
#   'RN_INDI': 605092,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e92a'),
#   'RN_INDI': 665753,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e92b'),
#   'RN_INDI': 731675,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e92c'),
#   'RN_INDI': 757190,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e92d'),
#   'RN_INDI': 826718,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e92e'),
#   'RN_INDI': 996207,
#   'BTH_YYYY': 1972},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e92f'),
#   'RN_INDI': 203261,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e930'),
#   'RN_INDI': 306433,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e931'),
#   'RN_INDI': 385559,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e932'),
#   'RN_INDI': 416604,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e933'),
#   'RN_INDI': 527979,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e934'),
#   'RN_INDI': 739343,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e935'),
#   'RN_INDI': 783799,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e936'),
#   'RN_INDI': 828317,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e937'),
#   'RN_INDI': 841175,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e938'),
#   'RN_INDI': 986005,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e939'),
#   'RN_INDI': 1004971,
#   'BTH_YYYY': 1973},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e93a'),
#   'RN_INDI': 51105,
#   'BTH_YYYY': 1974},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e93b'),
#   'RN_INDI': 176242,
#   'BTH_YYYY': 1974},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e93c'),
#   'RN_INDI': 203402,
#   'BTH_YYYY': 1974},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e93d'),
#   'RN_INDI': 349647,
#   'BTH_YYYY': 1974},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e93e'),
#   'RN_INDI': 420854,
#   'BTH_YYYY': 1974},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046e93f'),
#   'RN_INDI': 423842,
#   'BTH_YYYY': 1974},
# ...
#   'RN_INDI': 971748,
#   'BTH_YYYY': 1997},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea7b'),
#   'RN_INDI': 225503,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea7c'),
#   'RN_INDI': 269902,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea7d'),
#   'RN_INDI': 302781,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea7e'),
#   'RN_INDI': 326883,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea7f'),
#   'RN_INDI': 335411,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea80'),
#   'RN_INDI': 468958,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea81'),
#   'RN_INDI': 539874,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea82'),
#   'RN_INDI': 695844,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea83'),
#   'RN_INDI': 787867,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea84'),
#   'RN_INDI': 806727,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea85'),
#   'RN_INDI': 905339,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea86'),
#   'RN_INDI': 916359,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea87'),
#   'RN_INDI': 951174,
#   'BTH_YYYY': 1998},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea88'),
#   'RN_INDI': 73610,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea89'),
#   'RN_INDI': 163969,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea8a'),
#   'RN_INDI': 179020,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea8b'),
#   'RN_INDI': 238712,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea8c'),
#   'RN_INDI': 308173,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea8d'),
#   'RN_INDI': 310621,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea8e'),
#   'RN_INDI': 425871,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea8f'),
#   'RN_INDI': 486937,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea90'),
#   'RN_INDI': 563494,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea91'),
#   'RN_INDI': 760126,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea92'),
#   'RN_INDI': 879593,
#   'BTH_YYYY': 1999},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea93'),
#   'RN_INDI': 82310,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea94'),
#   'RN_INDI': 84893,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea95'),
#   'RN_INDI': 161487,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea96'),
#   'RN_INDI': 176406,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea97'),
#   'RN_INDI': 257664,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea98'),
#   'RN_INDI': 466981,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea99'),
#   'RN_INDI': 577639,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea9a'),
#   'RN_INDI': 708939,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea9b'),
#   'RN_INDI': 753723,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea9c'),
#   'RN_INDI': 813440,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea9d'),
#   'RN_INDI': 941612,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea9e'),
#   'RN_INDI': 950411,
#   'BTH_YYYY': 2000},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ea9f'),
#   'RN_INDI': 20218,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaa0'),
#   'RN_INDI': 49262,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaa1'),
#   'RN_INDI': 134908,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaa2'),
#   'RN_INDI': 158558,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaa3'),
#   'RN_INDI': 208900,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaa4'),
#   'RN_INDI': 250136,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaa5'),
#   'RN_INDI': 263640,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaa6'),
#   'RN_INDI': 273079,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaa7'),
#   'RN_INDI': 396613,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaa8'),
#   'RN_INDI': 413012,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaa9'),
#   'RN_INDI': 519015,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaaa'),
#   'RN_INDI': 546675,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaab'),
#   'RN_INDI': 561648,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaac'),
#   'RN_INDI': 864522,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaad'),
#   'RN_INDI': 870877,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaae'),
#   'RN_INDI': 899365,
#   'BTH_YYYY': 2001},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaaf'),
#   'RN_INDI': 3085,
#   'BTH_YYYY': 2002},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eab0'),
#   'RN_INDI': 299738,
#   'BTH_YYYY': 2002},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eab1'),
#   'RN_INDI': 364349,
#   'BTH_YYYY': 2002},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eab2'),
#   'RN_INDI': 404279,
#   'BTH_YYYY': 2002},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eab3'),
#   'RN_INDI': 716015,
#   'BTH_YYYY': 2002},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eab4'),
#   'RN_INDI': 802803,
#   'BTH_YYYY': 2002},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eab5'),
#   'RN_INDI': 938422,
#   'BTH_YYYY': 2002},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eab6'),
#   'RN_INDI': 5835,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eab7'),
#   'RN_INDI': 18010,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eab8'),
#   'RN_INDI': 92285,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eab9'),
#   'RN_INDI': 161387,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaba'),
#   'RN_INDI': 170806,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eabb'),
#   'RN_INDI': 221998,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eabc'),
#   'RN_INDI': 314923,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eabd'),
#   'RN_INDI': 601775,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eabe'),
#   'RN_INDI': 631006,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eabf'),
#   'RN_INDI': 636187,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eac0'),
#   'RN_INDI': 863171,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eac1'),
#   'RN_INDI': 963693,
#   'BTH_YYYY': 2003},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eac2'),
#   'RN_INDI': 28170,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eac3'),
#   'RN_INDI': 325390,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eac4'),
#   'RN_INDI': 440692,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eac5'),
#   'RN_INDI': 645066,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eac6'),
#   'RN_INDI': 744544,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eac7'),
#   'RN_INDI': 759439,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eac8'),
#   'RN_INDI': 772460,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eac9'),
#   'RN_INDI': 973079,
#   'BTH_YYYY': 2004},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaca'),
#   'RN_INDI': 151244,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eacb'),
#   'RN_INDI': 248794,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eacc'),
#   'RN_INDI': 300615,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eacd'),
#   'RN_INDI': 314882,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eace'),
#   'RN_INDI': 398665,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eacf'),
#   'RN_INDI': 407118,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ead0'),
#   'RN_INDI': 658189,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ead1'),
#   'RN_INDI': 658751,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ead2'),
#   'RN_INDI': 758751,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ead3'),
#   'RN_INDI': 847505,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ead4'),
#   'RN_INDI': 911175,
#   'BTH_YYYY': 2005},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ead5'),
#   'RN_INDI': 2086938,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ead6'),
#   'RN_INDI': 2086947,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ead7'),
#   'RN_INDI': 2086957,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ead8'),
#   'RN_INDI': 2087001,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046ead9'),
#   'RN_INDI': 2087359,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eada'),
#   'RN_INDI': 2088391,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eadb'),
#   'RN_INDI': 2088649,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eadc'),
#   'RN_INDI': 2089304,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eadd'),
#   'RN_INDI': 2089654,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eade'),
#   'RN_INDI': 2089788,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eadf'),
#   'RN_INDI': 2092954,
#   'BTH_YYYY': 2006},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eae0'),
#   'RN_INDI': 2000020,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eae1'),
#   'RN_INDI': 2010719,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eae2'),
#   'RN_INDI': 2018681,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eae3'),
#   'RN_INDI': 2018912,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eae4'),
#   'RN_INDI': 2020810,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eae5'),
#   'RN_INDI': 2026212,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eae6'),
#   'RN_INDI': 2042563,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eae7'),
#   'RN_INDI': 2042976,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eae8'),
#   'RN_INDI': 2072334,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eae9'),
#   'RN_INDI': 2077234,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaea'),
#   'RN_INDI': 2078627,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaeb'),
#   'RN_INDI': 2083536,
#   'BTH_YYYY': 2007},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaec'),
#   'RN_INDI': 2029345,
#   'BTH_YYYY': 2008},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaed'),
#   'RN_INDI': 2032575,
#   'BTH_YYYY': 2008},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaee'),
#   'RN_INDI': 2035362,
#   'BTH_YYYY': 2008},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaef'),
#   'RN_INDI': 2040013,
#   'BTH_YYYY': 2008},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaf0'),
#   'RN_INDI': 2061761,
#   'BTH_YYYY': 2008},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaf1'),
#   'RN_INDI': 2071250,
#   'BTH_YYYY': 2008},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaf2'),
#   'RN_INDI': 2084440,
#   'BTH_YYYY': 2008},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaf3'),
#   'RN_INDI': 2018134,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaf4'),
#   'RN_INDI': 2023673,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaf5'),
#   'RN_INDI': 2038651,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaf6'),
#   'RN_INDI': 2040254,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaf7'),
#   'RN_INDI': 2058808,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaf8'),
#   'RN_INDI': 2061873,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaf9'),
#   'RN_INDI': 2064588,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eafa'),
#   'RN_INDI': 2080462,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eafb'),
#   'RN_INDI': 2080886,
#   'BTH_YYYY': 2009},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eafc'),
#   'RN_INDI': 2003497,
#   'BTH_YYYY': 2010},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eafd'),
#   'RN_INDI': 2007534,
#   'BTH_YYYY': 2010},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eafe'),
#   'RN_INDI': 2013766,
#   'BTH_YYYY': 2010},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eaff'),
#   'RN_INDI': 2022479,
#   'BTH_YYYY': 2010},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb00'),
#   'RN_INDI': 2043266,
#   'BTH_YYYY': 2010},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb01'),
#   'RN_INDI': 2070235,
#   'BTH_YYYY': 2010},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb02'),
#   'RN_INDI': 2075679,
#   'BTH_YYYY': 2010},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb03'),
#   'RN_INDI': 2011515,
#   'BTH_YYYY': 2011},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb04'),
#   'RN_INDI': 2026146,
#   'BTH_YYYY': 2011},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb05'),
#   'RN_INDI': 2048842,
#   'BTH_YYYY': 2011},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb06'),
#   'RN_INDI': 2052260,
#   'BTH_YYYY': 2011},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb07'),
#   'RN_INDI': 2058256,
#   'BTH_YYYY': 2011},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb08'),
#   'RN_INDI': 2060095,
#   'BTH_YYYY': 2011},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb09'),
#   'RN_INDI': 2061241,
#   'BTH_YYYY': 2011},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb0a'),
#   'RN_INDI': 2019267,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb0b'),
#   'RN_INDI': 2024260,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb0c'),
#   'RN_INDI': 2029436,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb0d'),
#   'RN_INDI': 2042518,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb0e'),
#   'RN_INDI': 2045636,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb0f'),
#   'RN_INDI': 2062864,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb10'),
#   'RN_INDI': 2066728,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb11'),
#   'RN_INDI': 2078794,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb12'),
#   'RN_INDI': 3000357,
#   'BTH_YYYY': 2012},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb13'),
#   'RN_INDI': 2000846,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb14'),
#   'RN_INDI': 2004812,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb15'),
#   'RN_INDI': 2007337,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb16'),
#   'RN_INDI': 2018770,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb17'),
#   'RN_INDI': 2020718,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb18'),
#   'RN_INDI': 2037391,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb19'),
#   'RN_INDI': 2037727,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb1a'),
#   'RN_INDI': 2062330,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb1b'),
#   'RN_INDI': 2073308,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb1c'),
#   'RN_INDI': 2074479,
#   'BTH_YYYY': 2013},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb1d'),
#   'RN_INDI': 2002123,
#   'BTH_YYYY': 2014},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb1e'),
#   'RN_INDI': 2002417,
#   'BTH_YYYY': 2014},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb1f'),
#   'RN_INDI': 2041982,
#   'BTH_YYYY': 2014},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb20'),
#   'RN_INDI': 2044310,
#   'BTH_YYYY': 2014},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb21'),
#   'RN_INDI': 2063620,
#   'BTH_YYYY': 2014},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb22'),
#   'RN_INDI': 2070327,
#   'BTH_YYYY': 2014},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb23'),
#   'RN_INDI': 2080025,
#   'BTH_YYYY': 2014,
#   'DTH_YYYYMM': 202004},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb24'),
#   'RN_INDI': 2084429,
#   'BTH_YYYY': 2014},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb25'),
#   'RN_INDI': 2037151,
#   'BTH_YYYY': 2015},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb26'),
#   'RN_INDI': 2040322,
#   'BTH_YYYY': 2015},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb27'),
#   'RN_INDI': 2048579,
#   'BTH_YYYY': 2015},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb28'),
#   'RN_INDI': 2057743,
#   'BTH_YYYY': 2015},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb29'),
#   'RN_INDI': 2063541,
#   'BTH_YYYY': 2015},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb2a'),
#   'RN_INDI': 2070251,
#   'BTH_YYYY': 2015},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb2b'),
#   'RN_INDI': 2077125,
#   'BTH_YYYY': 2015},
#  {'_id': ObjectId('64d2fd0b4adce6a8b046eb2c'),
#   'RN_INDI': 3000758,
#   'BTH_YYYY': 2015}]

# %%
df_BND = pd.DataFrame(list_BND)

# %%
df_BND
# Out:
#                           _id  RN_INDI BTH_YYYY  DTH_YYYYMM     COD1     COD2
# 0    64d2fd0b4adce6a8b046e745   294364   1921LE    200707.0  T08-T14  W00-W19
# 1    64d2fd0b4adce6a8b046e746   646257   1921LE    200805.0  A15-A19      NaN
# 2    64d2fd0b4adce6a8b046e747   733575   1921LE    201309.0      G30      NaN
# 3    64d2fd0b4adce6a8b046e748   966199   1921LE    201409.0      J69      NaN
# 4    64d2fd0b4adce6a8b046e749   972598   1921LE    201205.0      C44      NaN
# ..                        ...      ...      ...         ...      ...      ...
# 995  64d2fd0b4adce6a8b046eb28  2057743     2015         NaN      NaN      NaN
# 996  64d2fd0b4adce6a8b046eb29  2063541     2015         NaN      NaN      NaN
# 997  64d2fd0b4adce6a8b046eb2a  2070251     2015         NaN      NaN      NaN
# 998  64d2fd0b4adce6a8b046eb2b  2077125     2015         NaN      NaN      NaN
# 999  64d2fd0b4adce6a8b046eb2c  3000758     2015         NaN      NaN      NaN
#
# [1000 rows x 6 columns]

# %%
df_BND.to_csv('./NSC2_BND.csv')
